# %%
#7
a,b=map(int,input().split(','))
if a<0 and b<0:
    print('Yes')
else:
    print('No')
# Out:
# No

# %%
#8
a,b=map(str,input().split(','))
if len(a)>len(b):
    print('True')
else:
    print('False')
# Out:
# False

# %%
#9
a = int(input("a = "))
b = int(input("b = "))
c = int(input("c = "))
if (a + b > c) and (a + c > b) and (b + c > a):
    print("Yes")
else:
    print("No")

# %%
#10
ds=[int(x) for x in input('nhap cac so lan luot, cach nhau bang dau phay').split(',')]
s=ds[0]
for i in ds:
    if s<i:
        s=i
print('gia tri lon nhat ',s)

# %%
a,b,c=map(int,input().split(','))
if a+b>c and a+c>b and b+c>a:
    if a==b==c:
        print('tam giac deu')
    elif a==b or a==c or b==c:
        print('tam giac can')
    else:
        print('tam giac thuong')
else:
    print('ko phai tam giac')
# Out:
# tam giac thuong

# %%
#14
a,b=map(float,input().split(','))
if a==0 and b==0:
    print('vo so nghiem')
elif a==0 and b!=0:
    print('pt vo nghiem')
else:
    x=-b/a
    print('pt co nghiem= ',f'{x:.2f}')
# Out:
# pt co nghiem=  -1.50

# %%
#15
n=float(input())
if n>=8:
    print('gioi')
elif n>=6.5:
    print('kha')
elif n>=5:
    print('tb')
else:
    print('yeu')
# Out:
# kha

# %%
#16
n=float(input())
if n>0:
    n+=0.5
    print(int(n))
else:
    n-=0.5
    print(int(n))
# Out:
# -5

# %%
#17
ds=[float(x) for x in input().split(',')]
boi=ds[1]/ds[0]
check=0
for i in range(3):
    if ds[i+1]/ds[i]==boi:
        check+=1
if check==3:
    print('day la 1 cap so nhan')
else:
    print('day ko pk la cap so nhan')
# Out:
# day ko pk la cap so nhan
