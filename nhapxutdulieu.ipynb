# %%
#1
print('Hello World!')
# Out:
# Hello World!

# %%
#2
ten=input('nhap ten ')
print('Xin chao',ten)
# Out:
# Xin chao nguyen  van a

# %%
a=int(input('nhap a '))
b=int(input('nhap b '))
print(a+b)
print(a-b)
print(a*b)
print(a//b)
print(a%b)
print(a/b)
# Out:
# 5
# 1
# 6
# 1
# 1
# 1.5

# %%
#4
a1, b1, c1, a2, b2, A3 = map(float, input().split())
tb = (a1 + b1 + c1 + (a2 + b2) * 2 + A3 * 3) / 10
print(f"{tb:.1f}")
# Out:
# 4.20

# %%
#5
a,b=map(int,input("nhap so a va b lan luot la ").split())
print(a**b)
# Out:
# 8

# %%
#6
a=input('nhap chu cai ')
print(ord(a))
print(a.upper())

# %%
#7
A=((13**2)*3)+5
B=13**2*3+5
print(A, B)
# Out:
# 512 512

# %%
#8
doC=int(input('nhap nhiet hien tai o do C '))
print('F=',f"{9/5*doC+32:.2f}")
# Out:
# F= 32.00

# %%
#9
x=int(input('gia tien '))
tst=10+x*1.4
print(f"{tst:.2f}")
# Out:
# 24.00

# %%
#10
,b,c=map(str,input('nhap ten di ').split(','))
print(c,',',b,'and',a)
# Out:
#  ood thanh ,  oh= huy and Nguyen thanh dat

# %%
#11
h=int(input('nhap gio '))
m=int(input('nhap phut '))
print('số giờ',h,'và số phút',m,'chuyển sang số giây là ',h*3600+m*600)
# Out:
# số giờ 2 và số phút 3 chuyển sang số giây là  9000

# %%
#12
dodai=int(input('nhap do dai canh '))
print('so mieng dan can thiet de bao phu toan bo khoi lap phuon',dodai**2*6)
# Out:
# so mieng dan can thiet de bao phu toan bo khoi lap phuon 24

# %%
#13
a=int(input('nhap a='))
b=int(input())
print('hang don vi cua phep tinh tich giua a va b ',(a*b)%10)
# Out:
# hang don vi cua phep tinh tich giua a va b  2

# %%
#14
a=int(input())
b=int(input())
print('gia tri truoc khi doi ',a,b)
a+=b
b=a-b
a=a-b
print('gia tri sau khi doi ',a,b)
# Out:
# gia tri truoc khi doi  321 123
# gia tri sau khi doi  123 321

# %%
#16
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
#17
print('*')
print('***')
print('*'*5)
# Out:
# *
# ***
# *****

# %%
#W2A18
print('### # #   ### ###')
print(' #  #  #   #   #')
print(' #  #   #  #   #')
print(' #  #  #   #   #')
print(' #  # #    #   #')
# Out:
# ### # #   ### ###
#  #  #  #   #   #
#  #  #   #  #   #
#  #  #  #   #   #
#  #  # #    #   #

# %%
#19
print('Monday  \nTuesday \nWednesday \nThursday \nFriday \nSaturday \nSunday')
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#21
for i in range(10):
    print('Hello, world ')
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
